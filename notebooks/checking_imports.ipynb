# %%
import random_table as rt

# %%
table = rt.load_table("../data/example-table.csv")

# %%
table.columns
# Out:
# Index(['Wheather', 'Time of day', 'Environment', 'Environmental hazard',
#        'NPCs'],
#       dtype='str')

# %%
table.columns.to.list()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 table.columns.to.list()
#
# AttributeError: 'Index' object has no attribute 'to'
