# %% [markdown]
# Random Table Generator
#
# -Take in csv files(future: maybe excel?)
# -CSV file an have number of columns, each column has header/title (within reason)
# -columns can have differnet lengths
#
# -need to an exemple csv file
# -happy to run in jupyter notebook

# %%
import pandas as pd

# %%
# function to load csv file

example_table = pd.read_csv("../data/example-table.csv")

# %%
# function to remind me what categories are available

# example_table.dropna()
# example_table

# example_table.columns

# example_table.columns.str.strip()

# example_table.columns.str.strip().str.lower()

example_table =example_table.columns.str.strip()
example_table
# Out:
# Index(['Wheather', 'Time of day', 'Environment', 'Environmental hazard',
#        'NPCs'],
#       dtype='str')

# %%
#example_table["Wheather"]

# %%
def load_table(filepath):
    example_table =pd.read_csv(filepath)
    example_table.columns = example_table.columns.str.strip()
    return example_table

# %%
example_table_2 = load_table("../data/example-table.csv")

example_table_2.columns
# Out:
# Index(['Wheather', 'Time of day', 'Environment', 'Environmental hazard',
#        'NPCs'],
#       dtype='str')

# %% [markdown]
# Testing
# - arrange
# - act
# - assert

# %%
# function  that  given category can randomly select and print it
